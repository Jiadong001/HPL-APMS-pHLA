# %% [markdown]
# Input:
# - HLA-A*02:02, TIQQCQSPT
# - HLA-A*02:01, DQTYNEMGD

# %% [markdown]
# ---
# # algorithm 1a -> HLA-A*02:02

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:02"
init_peptide = "TIQQCQSPT"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="1a"
                                        )
# When iteration is 4, GPU(3090) takes 15s while CPU takes 300s.
# batch=64, 3000M
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:02, given peptide: TIQQCQSPT | binding porbability: 0.0035
# ************** Run algorithm-1a **************
# Iteration-1, mutant_pool size: 171
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSNT | 8 P->N | binding probability: 0.4029
# source peptide: TIQQCQSPT, mutated peptide: TIQQIQSPT | 5 C->I | binding probability: 0.6952
# source peptide: TIQQCQSPT, mutated peptide: TIQNCQSPT | 4 Q->N | binding probability: 0.7288
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSYT | 8 P->Y | binding probability: 0.7901
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSFT | 8 P->F | binding probability: 0.8279
# Iteration-2, mutant_pool size: 753
# source peptide: TIQQCQSFT, mutated peptide: TIQQMQSFT | 5 C->M | binding probability: 0.9941
# source peptide: TIQQCQSYT, mutated peptide: TIQQVQSYT | 5 C->V | binding probability: 0.9956
# source peptide: TIQQIQSPT, mutated peptide: TIQQIQSVT | 8 P->V | binding probability: 0.9956
# source peptide: TIQQCQSFT, mutated peptide: TIQQLQSFT | 5 C->L | binding probability: 0.9961
# source peptide: TIQQCQSYT, mutated peptide: TIQQLQSYT | 5 C->L | binding probability: 0.9967
# Iteration-3, mutant_pool size: 665
# source peptide: TIQQLQSFT, mutated peptide: TIQQLQSFV | 9 T->V | binding probability: 0.9993
# source peptide: TIQQLQSYT, mutated peptide: LIQQLQSYT | 1 T->L | binding probability: 0.9994
# source peptide: TIQQIQSVT, mutated peptide: TIAQIQSVT | 3 Q->A | binding probability: 0.9994
# source peptide: TIQQLQSYT, mutated peptide: IIQQLQSYT | 1 T->I | binding probability: 0.9995
# source peptide: TIQQIQSVT, mutated peptide: TISQIQSVT | 3 Q->S | binding probability: 0.9996
# Iteration-4, mutant_pool size: 570
# source peptide: TISQIQSVT, mutated peptide: TISHIQSVT | 4 Q->H | binding probability: 0.9999
# source peptide: TIAQIQSVT, mutated peptide: TIAQIQSVL | 9 T->L | binding probability: 0.9999
# source peptide: TIAQIQSVT, mutated peptide: TIAQIQSVI | 9 T->I | binding probability: 0.9999
# source peptide: TIQQLQSFV, mutated peptide: TISQLQSFV | 3 Q->S | binding probability: 0.9999
# source peptide: TISQIQSVT, mutated peptide: IISQIQSVT | 1 T->I | binding probability: 0.9999
# Iteration-5, mutant_pool size: 474
# source peptide: TIAQIQSVL, mutated peptide: TIAPIQSVL | 4 Q->P | binding probability: 1.0000
# source peptide: TIAQIQSVL, mutated peptide: TIAEIQSVL | 4 Q->E | binding probability: 1.0000
# source peptide: TIAQIQSVL, mutated peptide: TIAQIVSVL | 6 Q->V | binding probability: 1.0000
# source peptide: TISHIQSVT, mutated peptide: TISHIQSVV | 9 T->V | binding probability: 1.0000
# source peptide: TISQLQSFV, mutated peptide: TISHLQSFV | 4 Q->H | binding probability: 1.0000
# -------------- Algorithm-1a done --------------

# %%
given_HLA = "HLA-A*02:02"

import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")
# Out:
# target/all: 5011/924412
# pos/target: 2507/5011
# neg/target: 2504/5011

# %%
for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# TIQQCQSNT isn't in our dataset
# TIQQIQSPT isn't in our dataset
# TIQNCQSPT isn't in our dataset
# TIQQCQSYT isn't in our dataset
# TIQQCQSFT isn't in our dataset
# TIQQMQSFT isn't in our dataset
# TIQQVQSYT isn't in our dataset
# TIQQIQSVT isn't in our dataset
# TIQQLQSFT isn't in our dataset
# TIQQLQSYT isn't in our dataset
# TIQQLQSFV isn't in our dataset
# LIQQLQSYT isn't in our dataset
# TIAQIQSVT isn't in our dataset
# IIQQLQSYT isn't in our dataset
# TISQIQSVT isn't in our dataset
# TISHIQSVT isn't in our dataset
# TIAQIQSVL isn't in our dataset
# TIAQIQSVI isn't in our dataset
# TISQLQSFV isn't in our dataset
# IISQIQSVT isn't in our dataset
# TIAPIQSVL isn't in our dataset
# TIAEIQSVL isn't in our dataset
# TIAQIVSVL isn't in our dataset
# TISHIQSVV isn't in our dataset
# TISHLQSFV isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSPT | binding porbability = 0.0032
# 2	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSNT | binding porbability = 0.0008
# 3	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQIQSPT | binding porbability = 0.0002
# 4	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQNCQSPT | binding porbability = 0.0020
# 5	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSYT | binding porbability = 0.0001
# 6	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSFT | binding porbability = 0.0001
# 7	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQMQSFT | binding porbability = 0.0004
# 8	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQVQSYT | binding porbability = 0.0000
# 9	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQIQSVT | binding porbability = 0.0000
# 10	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFT | binding porbability = 0.0000
# 11	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSYT | binding porbability = 0.0000
# 12	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFV | binding porbability = 0.9370
# 13	TransPHLA report: given HLA HLA-A*02:02, given peptide LIQQLQSYT | binding porbability = 0.0017
# 14	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAQIQSVT | binding porbability = 0.0000
# 15	TransPHLA report: given HLA HLA-A*02:02, given peptide IIQQLQSYT | binding porbability = 0.0002
# 16	TransPHLA report: given HLA HLA-A*02:02, given peptide TISQIQSVT | binding porbability = 0.0000
# 17	TransPHLA report: given HLA HLA-A*02:02, given peptide TISHIQSVT | binding porbability = 0.0003
# 18	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAQIQSVL | binding porbability = 0.8730
# 19	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAQIQSVI | binding porbability = 0.7600
# 20	TransPHLA report: given HLA HLA-A*02:02, given peptide TISQLQSFV | binding porbability = 0.9856
# 21	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQIQSVT | binding porbability = 0.0009
# 22	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAPIQSVL | binding porbability = 0.9993
# 23	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAEIQSVL | binding porbability = 0.9999
# 24	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAQIVSVL | binding porbability = 0.9896
# 25	TransPHLA report: given HLA HLA-A*02:02, given peptide TISHIQSVV | binding porbability = 0.9804
# 26	TransPHLA report: given HLA HLA-A*02:02, given peptide TISHLQSFV | binding porbability = 0.9821

# %% [markdown]
# # algorithm 1b -> HLA-A*02:02

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:02"
init_peptide = "TIQQCQSPT"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="1b"
                                        )
# When iteration is 4, GPU(3090) takes 15s while CPU takes 300s.
# batch=64, 3000M
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:02, given peptide: TIQQCQSPT | binding porbability: 0.0035
# ************** Run algorithm-1b **************
# Iteration-1, mutant_pool size: 171
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSFT | 8 P->F | binding probability: 0.8279
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSYT | 8 P->Y | binding probability: 0.7901
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSNT | 8 P->N | binding probability: 0.4029
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSWT | 8 P->W | binding probability: 0.1483
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSQT | 8 P->Q | binding probability: 0.1375
# Iteration-2, mutant_pool size: 760
# source peptide: TIQQCQSFT, mutated peptide: TIQQLQSFT | 5 C->L | binding probability: 0.9961
# source peptide: TIQQCQSFT, mutated peptide: TIQQMQSFT | 5 C->M | binding probability: 0.9941
# source peptide: TIQQCQSFT, mutated peptide: TIQQNQSFT | 5 C->N | binding probability: 0.9934
# source peptide: TIQQCQSFT, mutated peptide: TIQQVQSFT | 5 C->V | binding probability: 0.9933
# source peptide: TIQQCQSFT, mutated peptide: TIQQHQSFT | 5 C->H | binding probability: 0.9921
# Iteration-3, mutant_pool size: 665
# source peptide: TIQQLQSFT, mutated peptide: TIQQLQSFV | 9 T->V | binding probability: 0.9993
# source peptide: TIQQLQSFT, mutated peptide: TIQQLQSFA | 9 T->A | binding probability: 0.9992
# source peptide: TIQQLQSFT, mutated peptide: TIQQLQSFI | 9 T->I | binding probability: 0.9991
# source peptide: TIQQHQSFT, mutated peptide: TIQQHQSFI | 9 T->I | binding probability: 0.9990
# source peptide: TIQQLQSFT, mutated peptide: TIQQLQSFL | 9 T->L | binding probability: 0.9988
# Iteration-4, mutant_pool size: 570
# source peptide: TIQQLQSFL, mutated peptide: TIAQLQSFL | 3 Q->A | binding probability: 1.0000
# source peptide: TIQQLQSFL, mutated peptide: TISQLQSFL | 3 Q->S | binding probability: 0.9999
# source peptide: TIQQLQSFV, mutated peptide: TISQLQSFV | 3 Q->S | binding probability: 0.9999
# source peptide: TIQQLQSFL, mutated peptide: TITQLQSFL | 3 Q->T | binding probability: 0.9999
# source peptide: TIQQLQSFV, mutated peptide: TITQLQSFV | 3 Q->T | binding probability: 0.9999
# Iteration-5, mutant_pool size: 475
# source peptide: TISQLQSFV, mutated peptide: TISHLQSFV | 4 Q->H | binding probability: 1.0000
# source peptide: TITQLQSFV, mutated peptide: TITHLQSFV | 4 Q->H | binding probability: 1.0000
# source peptide: TITQLQSFV, mutated peptide: TITNLQSFV | 4 Q->N | binding probability: 1.0000
# source peptide: TISQLQSFV, mutated peptide: TISNLQSFV | 4 Q->N | binding probability: 1.0000
# source peptide: TIAQLQSFL, mutated peptide: TIAHLQSFL | 4 Q->H | binding probability: 1.0000
# -------------- Algorithm-1b done --------------

# %%
import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")

for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# target/all: 5011/924412
# pos/target: 2507/5011
# neg/target: 2504/5011
# TIQQCQSFT isn't in our dataset
# TIQQCQSYT isn't in our dataset
# TIQQCQSNT isn't in our dataset
# TIQQCQSWT isn't in our dataset
# TIQQCQSQT isn't in our dataset
# TIQQLQSFT isn't in our dataset
# TIQQMQSFT isn't in our dataset
# TIQQNQSFT isn't in our dataset
# TIQQVQSFT isn't in our dataset
# TIQQHQSFT isn't in our dataset
# TIQQLQSFV isn't in our dataset
# TIQQLQSFA isn't in our dataset
# TIQQLQSFI isn't in our dataset
# TIQQHQSFI isn't in our dataset
# TIQQLQSFL isn't in our dataset
# TIAQLQSFL isn't in our dataset
# TISQLQSFL isn't in our dataset
# TISQLQSFV isn't in our dataset
# TITQLQSFL isn't in our dataset
# TITQLQSFV isn't in our dataset
# TISHLQSFV isn't in our dataset
# TITHLQSFV isn't in our dataset
# TITNLQSFV isn't in our dataset
# TISNLQSFV isn't in our dataset
# TIAHLQSFL isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSPT | binding porbability = 0.0032
# 2	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSFT | binding porbability = 0.0001
# 3	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSYT | binding porbability = 0.0001
# 4	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSNT | binding porbability = 0.0008
# 5	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSWT | binding porbability = 0.0003
# 6	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSQT | binding porbability = 0.0000
# 7	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFT | binding porbability = 0.0000
# 8	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQMQSFT | binding porbability = 0.0004
# 9	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQNQSFT | binding porbability = 0.0000
# 10	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQVQSFT | binding porbability = 0.0000
# 11	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQHQSFT | binding porbability = 0.0000
# 12	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFV | binding porbability = 0.9370
# 13	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFA | binding porbability = 0.0880
# 14	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFI | binding porbability = 0.9741
# 15	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQHQSFI | binding porbability = 0.8615
# 16	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFL | binding porbability = 0.7923
# 17	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAQLQSFL | binding porbability = 0.9952
# 18	TransPHLA report: given HLA HLA-A*02:02, given peptide TISQLQSFL | binding porbability = 0.9532
# 19	TransPHLA report: given HLA HLA-A*02:02, given peptide TISQLQSFV | binding porbability = 0.9856
# 20	TransPHLA report: given HLA HLA-A*02:02, given peptide TITQLQSFL | binding porbability = 0.9715
# 21	TransPHLA report: given HLA HLA-A*02:02, given peptide TITQLQSFV | binding porbability = 0.9698
# 22	TransPHLA report: given HLA HLA-A*02:02, given peptide TISHLQSFV | binding porbability = 0.9821
# 23	TransPHLA report: given HLA HLA-A*02:02, given peptide TITHLQSFV | binding porbability = 0.9903
# 24	TransPHLA report: given HLA HLA-A*02:02, given peptide TITNLQSFV | binding porbability = 0.9605
# 25	TransPHLA report: given HLA HLA-A*02:02, given peptide TISNLQSFV | binding porbability = 0.9935
# 26	TransPHLA report: given HLA HLA-A*02:02, given peptide TIAHLQSFL | binding porbability = 0.9642

# %% [markdown]
# # algorithm 2a -> HLA-A*02:02

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True     # GPU
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:02"
init_peptide = "TIQQCQSPT"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="2a"
                                        )
# When iteration is 4, GPU(3090) takes 14s while CPU takes 170s.
# When num_mutation=3, num_peptides=10, not just one position changed at iteration-3
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:02, given peptide: TIQQCQSPT | binding porbability: 0.0035
# ************** Run algorithm-2a **************
# Iteration-1, mutant_pool size: 19
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSQT | 8 P->Q | binding probability: 0.1375
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSWT | 8 P->W | binding probability: 0.1483
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSNT | 8 P->N | binding probability: 0.4029
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSYT | 8 P->Y | binding probability: 0.7901
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSFT | 8 P->F | binding probability: 0.8279
# Iteration-2, mutant_pool size: 95
# source peptide: TIQQCQSYT, mutated peptide: TIQQMQSYT | 5 C->M | binding probability: 0.9941
# source peptide: TIQQCQSFT, mutated peptide: TIQQMQSFT | 5 C->M | binding probability: 0.9941
# source peptide: TIQQCQSYT, mutated peptide: TIQQVQSYT | 5 C->V | binding probability: 0.9956
# source peptide: TIQQCQSFT, mutated peptide: TIQQLQSFT | 5 C->L | binding probability: 0.9961
# source peptide: TIQQCQSYT, mutated peptide: TIQQLQSYT | 5 C->L | binding probability: 0.9967
# Iteration-3, mutant_pool size: 95
# source peptide: TIQQLQSYT, mutated peptide: MIQQLQSYT | 1 T->M | binding probability: 0.9991
# source peptide: TIQQVQSYT, mutated peptide: IIQQVQSYT | 1 T->I | binding probability: 0.9991
# source peptide: TIQQLQSYT, mutated peptide: FIQQLQSYT | 1 T->F | binding probability: 0.9993
# source peptide: TIQQLQSYT, mutated peptide: LIQQLQSYT | 1 T->L | binding probability: 0.9994
# source peptide: TIQQLQSYT, mutated peptide: IIQQLQSYT | 1 T->I | binding probability: 0.9995
# Iteration-4, mutant_pool size: 95
# source peptide: IIQQLQSYT, mutated peptide: IISQLQSYT | 3 Q->S | binding probability: 0.9998
# source peptide: FIQQLQSYT, mutated peptide: FIQQLQSYV | 9 T->V | binding probability: 0.9998
# source peptide: FIQQLQSYT, mutated peptide: FIQQLQSYA | 9 T->A | binding probability: 0.9999
# source peptide: FIQQLQSYT, mutated peptide: FIQQLQSYL | 9 T->L | binding probability: 0.9999
# source peptide: FIQQLQSYT, mutated peptide: FIQQLQSYI | 9 T->I | binding probability: 0.9999
# Iteration-5, mutant_pool size: 95
# source peptide: FIQQLQSYI, mutated peptide: FIAQLQSYI | 3 Q->A | binding probability: 1.0000
# source peptide: IISQLQSYT, mutated peptide: IISQLQSYL | 9 T->L | binding probability: 1.0000
# source peptide: IISQLQSYT, mutated peptide: IISQLQSYI | 9 T->I | binding probability: 1.0000
# source peptide: FIQQLQSYL, mutated peptide: FIQDLQSYL | 4 Q->D | binding probability: 1.0000
# source peptide: FIQQLQSYL, mutated peptide: FIQHLQSYL | 4 Q->H | binding probability: 1.0000
# -------------- Algorithm-2a done --------------

# %%
given_HLA = "HLA-A*02:02"

import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")
# Out:
# target/all: 5011/924412
# pos/target: 2507/5011
# neg/target: 2504/5011

# %%
for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# TIQQCQSQT isn't in our dataset
# TIQQCQSWT isn't in our dataset
# TIQQCQSNT isn't in our dataset
# TIQQCQSYT isn't in our dataset
# TIQQCQSFT isn't in our dataset
# TIQQMQSYT isn't in our dataset
# TIQQMQSFT isn't in our dataset
# TIQQVQSYT isn't in our dataset
# TIQQLQSFT isn't in our dataset
# TIQQLQSYT isn't in our dataset
# MIQQLQSYT isn't in our dataset
# IIQQVQSYT isn't in our dataset
# FIQQLQSYT isn't in our dataset
# LIQQLQSYT isn't in our dataset
# IIQQLQSYT isn't in our dataset
# IISQLQSYT isn't in our dataset
# FIQQLQSYV isn't in our dataset
# FIQQLQSYA isn't in our dataset
# FIQQLQSYL isn't in our dataset
# FIQQLQSYI isn't in our dataset
# FIAQLQSYI isn't in our dataset
# IISQLQSYL isn't in our dataset
# IISQLQSYI isn't in our dataset
# FIQDLQSYL isn't in our dataset
# FIQHLQSYL isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSPT | binding porbability = 0.0032
# 2	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSQT | binding porbability = 0.0000
# 3	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSWT | binding porbability = 0.0003
# 4	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSNT | binding porbability = 0.0008
# 5	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSYT | binding porbability = 0.0001
# 6	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSFT | binding porbability = 0.0001
# 7	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQMQSYT | binding porbability = 0.0000
# 8	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQMQSFT | binding porbability = 0.0004
# 9	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQVQSYT | binding porbability = 0.0000
# 10	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFT | binding porbability = 0.0000
# 11	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSYT | binding porbability = 0.0000
# 12	TransPHLA report: given HLA HLA-A*02:02, given peptide MIQQLQSYT | binding porbability = 0.0016
# 13	TransPHLA report: given HLA HLA-A*02:02, given peptide IIQQVQSYT | binding porbability = 0.0001
# 14	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQQLQSYT | binding porbability = 0.0271
# 15	TransPHLA report: given HLA HLA-A*02:02, given peptide LIQQLQSYT | binding porbability = 0.0017
# 16	TransPHLA report: given HLA HLA-A*02:02, given peptide IIQQLQSYT | binding porbability = 0.0002
# 17	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQLQSYT | binding porbability = 0.0005
# 18	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQQLQSYV | binding porbability = 0.9948
# 19	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQQLQSYA | binding porbability = 0.9864
# 20	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQQLQSYL | binding porbability = 0.9923
# 21	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQQLQSYI | binding porbability = 0.9973
# 22	TransPHLA report: given HLA HLA-A*02:02, given peptide FIAQLQSYI | binding porbability = 0.9998
# 23	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQLQSYL | binding porbability = 0.9856
# 24	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQLQSYI | binding porbability = 0.9978
# 25	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQDLQSYL | binding porbability = 1.0000
# 26	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQHLQSYL | binding porbability = 0.9964

# %% [markdown]
# # algorithm-2b HLA-A*02:02

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True    # CPU
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:02"
init_peptide = "TIQQCQSPT"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="2b"
                                        )
# When iteration is 4, GPU(3090) takes 14s while CPU takes 170s.
# When num_mutation=3, num_peptides=10, not just one position changed at iteration-3
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:02, given peptide: TIQQCQSPT | binding porbability: 0.0035
# ************** Run algorithm-2b **************
# Iteration-1, mutant_pool size: 19
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSQT | 8 P->Q | binding probability: 0.1375
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSWT | 8 P->W | binding probability: 0.1483
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSNT | 8 P->N | binding probability: 0.4029
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSYT | 8 P->Y | binding probability: 0.7901
# source peptide: TIQQCQSPT, mutated peptide: TIQQCQSFT | 8 P->F | binding probability: 0.8279
# Iteration-2, mutant_pool size: 95
# source peptide: TIQQCQSYT, mutated peptide: TIQQMQSYT | 5 C->M | binding probability: 0.9941
# source peptide: TIQQCQSFT, mutated peptide: TIQQMQSFT | 5 C->M | binding probability: 0.9941
# source peptide: TIQQCQSYT, mutated peptide: TIQQVQSYT | 5 C->V | binding probability: 0.9956
# source peptide: TIQQCQSFT, mutated peptide: TIQQLQSFT | 5 C->L | binding probability: 0.9961
# source peptide: TIQQCQSYT, mutated peptide: TIQQLQSYT | 5 C->L | binding probability: 0.9967
# Iteration-3, mutant_pool size: 95
# source peptide: TIQQLQSYT, mutated peptide: MIQQLQSYT | 1 T->M | binding probability: 0.9991
# source peptide: TIQQVQSYT, mutated peptide: IIQQVQSYT | 1 T->I | binding probability: 0.9991
# source peptide: TIQQLQSYT, mutated peptide: FIQQLQSYT | 1 T->F | binding probability: 0.9993
# source peptide: TIQQLQSYT, mutated peptide: LIQQLQSYT | 1 T->L | binding probability: 0.9994
# source peptide: TIQQLQSYT, mutated peptide: IIQQLQSYT | 1 T->I | binding probability: 0.9995
# Iteration-4, mutant_pool size: 95
# source peptide: FIQQLQSYT, mutated peptide: FIAQLQSYT | 3 Q->A | binding probability: 0.9997
# source peptide: LIQQLQSYT, mutated peptide: LISQLQSYT | 3 Q->S | binding probability: 0.9997
# source peptide: IIQQLQSYT, mutated peptide: IIAQLQSYT | 3 Q->A | binding probability: 0.9997
# source peptide: IIQQVQSYT, mutated peptide: IISQVQSYT | 3 Q->S | binding probability: 0.9998
# source peptide: IIQQLQSYT, mutated peptide: IISQLQSYT | 3 Q->S | binding probability: 0.9998
# Iteration-5, mutant_pool size: 95
# source peptide: IISQLQSYT, mutated peptide: IISQLQSYL | 9 T->L | binding probability: 1.0000
# source peptide: IISQLQSYT, mutated peptide: IISQLQSYI | 9 T->I | binding probability: 1.0000
# source peptide: LISQLQSYT, mutated peptide: LISQLQSYL | 9 T->L | binding probability: 1.0000
# source peptide: IIAQLQSYT, mutated peptide: IIAQLQSYL | 9 T->L | binding probability: 1.0000
# source peptide: FIAQLQSYT, mutated peptide: FIAQLQSYL | 9 T->L | binding probability: 1.0000
# -------------- Algorithm-2b done --------------

# %%
import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")

for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# target/all: 5011/924412
# pos/target: 2507/5011
# neg/target: 2504/5011
# TIQQCQSQT isn't in our dataset
# TIQQCQSWT isn't in our dataset
# TIQQCQSNT isn't in our dataset
# TIQQCQSYT isn't in our dataset
# TIQQCQSFT isn't in our dataset
# TIQQMQSYT isn't in our dataset
# TIQQMQSFT isn't in our dataset
# TIQQVQSYT isn't in our dataset
# TIQQLQSFT isn't in our dataset
# TIQQLQSYT isn't in our dataset
# MIQQLQSYT isn't in our dataset
# IIQQVQSYT isn't in our dataset
# FIQQLQSYT isn't in our dataset
# LIQQLQSYT isn't in our dataset
# IIQQLQSYT isn't in our dataset
# FIAQLQSYT isn't in our dataset
# LISQLQSYT isn't in our dataset
# IIAQLQSYT isn't in our dataset
# IISQVQSYT isn't in our dataset
# IISQLQSYT isn't in our dataset
# IISQLQSYL isn't in our dataset
# IISQLQSYI isn't in our dataset
# LISQLQSYL isn't in our dataset
# IIAQLQSYL isn't in our dataset
# FIAQLQSYL isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSPT | binding porbability = 0.0032
# 2	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSQT | binding porbability = 0.0000
# 3	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSWT | binding porbability = 0.0003
# 4	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSNT | binding porbability = 0.0008
# 5	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSYT | binding porbability = 0.0001
# 6	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQCQSFT | binding porbability = 0.0001
# 7	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQMQSYT | binding porbability = 0.0000
# 8	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQMQSFT | binding porbability = 0.0004
# 9	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQVQSYT | binding porbability = 0.0000
# 10	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSFT | binding porbability = 0.0000
# 11	TransPHLA report: given HLA HLA-A*02:02, given peptide TIQQLQSYT | binding porbability = 0.0000
# 12	TransPHLA report: given HLA HLA-A*02:02, given peptide MIQQLQSYT | binding porbability = 0.0016
# 13	TransPHLA report: given HLA HLA-A*02:02, given peptide IIQQVQSYT | binding porbability = 0.0001
# 14	TransPHLA report: given HLA HLA-A*02:02, given peptide FIQQLQSYT | binding porbability = 0.0271
# 15	TransPHLA report: given HLA HLA-A*02:02, given peptide LIQQLQSYT | binding porbability = 0.0017
# 16	TransPHLA report: given HLA HLA-A*02:02, given peptide IIQQLQSYT | binding porbability = 0.0002
# 17	TransPHLA report: given HLA HLA-A*02:02, given peptide FIAQLQSYT | binding porbability = 0.0877
# 18	TransPHLA report: given HLA HLA-A*02:02, given peptide LISQLQSYT | binding porbability = 0.0013
# 19	TransPHLA report: given HLA HLA-A*02:02, given peptide IIAQLQSYT | binding porbability = 0.0010
# 20	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQVQSYT | binding porbability = 0.0001
# 21	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQLQSYT | binding porbability = 0.0005
# 22	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQLQSYL | binding porbability = 0.9856
# 23	TransPHLA report: given HLA HLA-A*02:02, given peptide IISQLQSYI | binding porbability = 0.9978
# 24	TransPHLA report: given HLA HLA-A*02:02, given peptide LISQLQSYL | binding porbability = 0.9540
# 25	TransPHLA report: given HLA HLA-A*02:02, given peptide IIAQLQSYL | binding porbability = 0.9994
# 26	TransPHLA report: given HLA HLA-A*02:02, given peptide FIAQLQSYL | binding porbability = 1.0000

# %% [markdown]
# --------
# # algorithm-1a HLA-A*02:01

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:01"
init_peptide = "DQTYNEMGD"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="1a"
                                        )
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:01, given peptide: DQTYNEMGD | binding porbability: 0.0000
# ************** Run algorithm-1a **************
# Iteration-1, mutant_pool size: 171
# source peptide: DQTYNEMGD, mutated peptide: DQTYNFMGD | 6 E->F | binding probability: 0.0052
# source peptide: DQTYNEMGD, mutated peptide: DQTYDEMGD | 5 N->D | binding probability: 0.0180
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGV | 9 D->V | binding probability: 0.0220
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGM | 9 D->M | binding probability: 0.0407
# source peptide: DQTYNEMGD, mutated peptide: DQTYNPMGD | 6 E->P | binding probability: 0.1719
# Iteration-2, mutant_pool size: 752
# source peptide: DQTYDEMGD, mutated peptide: DQFYDEMGD | 3 T->F | binding probability: 0.9637
# source peptide: DQTYNFMGD, mutated peptide: DQTYNFMGV | 9 D->V | binding probability: 0.9709
# source peptide: DQTYNPMGD, mutated peptide: DQTYNPMGE | 9 D->E | binding probability: 0.9785
# source peptide: DQTYDEMGD, mutated peptide: DQTQDEMGD | 4 Y->Q | binding probability: 0.9866
# source peptide: DQTYDEMGD, mutated peptide: DQTHDEMGD | 4 Y->H | binding probability: 0.9995
# Iteration-3, mutant_pool size: 663
# source peptide: DQTHDEMGD, mutated peptide: DQIHDEMGD | 3 T->I | binding probability: 0.9998
# source peptide: DQTHDEMGD, mutated peptide: DQTHDEMGE | 9 D->E | binding probability: 0.9999
# source peptide: DQTHDEMGD, mutated peptide: DQTHDEYGD | 7 M->Y | binding probability: 0.9999
# source peptide: DQTHDEMGD, mutated peptide: DQTHDEFGD | 7 M->F | binding probability: 0.9999
# source peptide: DQFYDEMGD, mutated peptide: HQFYDEMGD | 1 D->H | binding probability: 1.0000
# Iteration-4, mutant_pool size: 565
# source peptide: HQFYDEMGD, mutated peptide: HQFHDEMGD | 4 Y->H | binding probability: 1.0000
# source peptide: HQFYDEMGD, mutated peptide: HQFYDELGD | 7 M->L | binding probability: 1.0000
# source peptide: DQTHDEFGD, mutated peptide: DQLHDEFGD | 3 T->L | binding probability: 1.0000
# source peptide: HQFYDEMGD, mutated peptide: HQFQDEMGD | 4 Y->Q | binding probability: 1.0000
# source peptide: HQFYDEMGD, mutated peptide: HQFEDEMGD | 4 Y->E | binding probability: 1.0000
# Iteration-5, mutant_pool size: 472
# source peptide: HQFEDEMGD, mutated peptide: HQFEDEIGD | 7 M->I | binding probability: 1.0000
# source peptide: HQFEDEMGD, mutated peptide: HQFEDEMAD | 8 G->A | binding probability: 1.0000
# source peptide: HQFYDELGD, mutated peptide: HQFEDELGD | 4 Y->E | binding probability: 1.0000
# source peptide: HQFEDEMGD, mutated peptide: HQFEDEMKD | 8 G->K | binding probability: 1.0000
# source peptide: HQFEDEMGD, mutated peptide: HQFEDEMQD | 8 G->Q | binding probability: 1.0000
# -------------- Algorithm-1a done --------------

# %%
import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")

for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# target/all: 68830/924412
# pos/target: 34460/68830
# neg/target: 34370/68830
# DQTYNFMGD isn't in our dataset
# DQTYDEMGD isn't in our dataset
# DQTYNEMGV isn't in our dataset
# DQTYNEMGM isn't in our dataset
# DQTYNPMGD isn't in our dataset
# DQFYDEMGD isn't in our dataset
# DQTYNFMGV isn't in our dataset
# DQTYNPMGE isn't in our dataset
# DQTQDEMGD isn't in our dataset
# DQTHDEMGD isn't in our dataset
# DQIHDEMGD isn't in our dataset
# DQTHDEMGE isn't in our dataset
# DQTHDEYGD isn't in our dataset
# DQTHDEFGD isn't in our dataset
# HQFYDEMGD isn't in our dataset
# HQFHDEMGD isn't in our dataset
# HQFYDELGD isn't in our dataset
# DQLHDEFGD isn't in our dataset
# HQFQDEMGD isn't in our dataset
# HQFEDEMGD isn't in our dataset
# HQFEDEIGD isn't in our dataset
# HQFEDEMAD isn't in our dataset
# HQFEDELGD isn't in our dataset
# HQFEDEMKD isn't in our dataset
# HQFEDEMQD isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGD | binding porbability = 0.0000
# 2	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGD | binding porbability = 0.0000
# 3	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYDEMGD | binding porbability = 0.0000
# 4	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGV | binding porbability = 0.0000
# 5	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGM | binding porbability = 0.0000
# 6	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPMGD | binding porbability = 0.0000
# 7	TransPHLA report: given HLA HLA-A*02:01, given peptide DQFYDEMGD | binding porbability = 0.0000
# 8	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGV | binding porbability = 0.0061
# 9	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPMGE | binding porbability = 0.0000
# 10	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTQDEMGD | binding porbability = 0.0000
# 11	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTHDEMGD | binding porbability = 0.0000
# 12	TransPHLA report: given HLA HLA-A*02:01, given peptide DQIHDEMGD | binding porbability = 0.0000
# 13	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTHDEMGE | binding porbability = 0.0000
# 14	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTHDEYGD | binding porbability = 0.0000
# 15	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTHDEFGD | binding porbability = 0.0000
# 16	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFYDEMGD | binding porbability = 0.0000
# 17	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFHDEMGD | binding porbability = 0.0000
# 18	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFYDELGD | binding porbability = 0.0002
# 19	TransPHLA report: given HLA HLA-A*02:01, given peptide DQLHDEFGD | binding porbability = 0.0000
# 20	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFQDEMGD | binding porbability = 0.0000
# 21	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFEDEMGD | binding porbability = 0.0000
# 22	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFEDEIGD | binding porbability = 0.0007
# 23	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFEDEMAD | binding porbability = 0.0000
# 24	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFEDELGD | binding porbability = 0.0002
# 25	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFEDEMKD | binding porbability = 0.0002
# 26	TransPHLA report: given HLA HLA-A*02:01, given peptide HQFEDEMQD | binding porbability = 0.0000

# %% [markdown]
# # algorithm-1b HLA-A*02:01

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:01"
init_peptide = "DQTYNEMGD"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="1b"
                                        )
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:01, given peptide: DQTYNEMGD | binding porbability: 0.0000
# ************** Run algorithm-1b **************
# Iteration-1, mutant_pool size: 171
# source peptide: DQTYNEMGD, mutated peptide: DQTYNPMGD | 6 E->P | binding probability: 0.1719
# source peptide: DQTYNEMGD, mutated peptide: DQTYNFMGD | 6 E->F | binding probability: 0.0052
# source peptide: DQTYNEMGD, mutated peptide: DQTYNYMGD | 6 E->Y | binding probability: 0.0006
# source peptide: DQTYNEMGD, mutated peptide: DQTYNWMGD | 6 E->W | binding probability: 0.0005
# source peptide: DQTYNEMGD, mutated peptide: DQTYNDMGD | 6 E->D | binding probability: 0.0003
# Iteration-2, mutant_pool size: 760
# source peptide: DQTYNPMGD, mutated peptide: DQTYNPMGE | 9 D->E | binding probability: 0.9785
# source peptide: DQTYNFMGD, mutated peptide: DQTYNFMGV | 9 D->V | binding probability: 0.9709
# source peptide: DQTYNFMGD, mutated peptide: DQTYNFMGM | 9 D->M | binding probability: 0.9208
# source peptide: DQTYNFMGD, mutated peptide: DQTYNFMGL | 9 D->L | binding probability: 0.8728
# source peptide: DQTYNFMGD, mutated peptide: DQTYNFMGI | 9 D->I | binding probability: 0.8579
# Iteration-3, mutant_pool size: 665
# source peptide: DQTYNPMGE, mutated peptide: DQTYNPLGE | 7 M->L | binding probability: 0.9949
# source peptide: DQTYNFMGI, mutated peptide: DQTYNFVGI | 7 M->V | binding probability: 0.9893
# source peptide: DQTYNPMGE, mutated peptide: DQTYNPVGE | 7 M->V | binding probability: 0.9630
# source peptide: DQTYNFMGI, mutated peptide: DQTYNFAGI | 7 M->A | binding probability: 0.9447
# source peptide: DQTYNPMGE, mutated peptide: DQTYNPIGE | 7 M->I | binding probability: 0.9434
# Iteration-4, mutant_pool size: 570
# source peptide: DQTYNPLGE, mutated peptide: DQSYNPLGE | 3 T->S | binding probability: 0.9992
# source peptide: DQTYNPLGE, mutated peptide: DQIYNPLGE | 3 T->I | binding probability: 0.9937
# source peptide: DQTYNPLGE, mutated peptide: DQEYNPLGE | 3 T->E | binding probability: 0.9922
# source peptide: DQTYNPLGE, mutated peptide: DQNYNPLGE | 3 T->N | binding probability: 0.9896
# source peptide: DQTYNPIGE, mutated peptide: DQSYNPIGE | 3 T->S | binding probability: 0.9860
# Iteration-5, mutant_pool size: 475
# source peptide: DQSYNPLGE, mutated peptide: DQSVNPLGE | 4 Y->V | binding probability: 0.9998
# source peptide: DQSYNPLGE, mutated peptide: DQSLNPLGE | 4 Y->L | binding probability: 0.9995
# source peptide: DQSYNPLGE, mutated peptide: DQSKNPLGE | 4 Y->K | binding probability: 0.9993
# source peptide: DQSYNPLGE, mutated peptide: DQSFNPLGE | 4 Y->F | binding probability: 0.9992
# source peptide: DQSYNPLGE, mutated peptide: DQSINPLGE | 4 Y->I | binding probability: 0.9983
# -------------- Algorithm-1b done --------------

# %%
import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")

for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# target/all: 68830/924412
# pos/target: 34460/68830
# neg/target: 34370/68830
# DQTYNPMGD isn't in our dataset
# DQTYNFMGD isn't in our dataset
# DQTYNYMGD isn't in our dataset
# DQTYNWMGD isn't in our dataset
# DQTYNDMGD isn't in our dataset
# DQTYNPMGE isn't in our dataset
# DQTYNFMGV isn't in our dataset
# DQTYNFMGM isn't in our dataset
# DQTYNFMGL isn't in our dataset
# DQTYNFMGI isn't in our dataset
# DQTYNPLGE isn't in our dataset
# DQTYNFVGI isn't in our dataset
# DQTYNPVGE isn't in our dataset
# DQTYNFAGI isn't in our dataset
# DQTYNPIGE isn't in our dataset
# DQSYNPLGE isn't in our dataset
# DQIYNPLGE isn't in our dataset
# DQEYNPLGE isn't in our dataset
# DQNYNPLGE isn't in our dataset
# DQSYNPIGE isn't in our dataset
# DQSVNPLGE isn't in our dataset
# DQSLNPLGE isn't in our dataset
# DQSKNPLGE isn't in our dataset
# DQSFNPLGE isn't in our dataset
# DQSINPLGE isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGD | binding porbability = 0.0000
# 2	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPMGD | binding porbability = 0.0000
# 3	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGD | binding porbability = 0.0000
# 4	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNYMGD | binding porbability = 0.0000
# 5	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNWMGD | binding porbability = 0.0000
# 6	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNDMGD | binding porbability = 0.0000
# 7	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPMGE | binding porbability = 0.0000
# 8	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGV | binding porbability = 0.0061
# 9	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGM | binding porbability = 0.0000
# 10	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGL | binding porbability = 0.0014
# 11	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGI | binding porbability = 0.0113
# 12	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPLGE | binding porbability = 0.0000
# 13	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFVGI | binding porbability = 0.0901
# 14	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPVGE | binding porbability = 0.0000
# 15	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFAGI | binding porbability = 0.0093
# 16	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPIGE | binding porbability = 0.0000
# 17	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSYNPLGE | binding porbability = 0.0000
# 18	TransPHLA report: given HLA HLA-A*02:01, given peptide DQIYNPLGE | binding porbability = 0.0000
# 19	TransPHLA report: given HLA HLA-A*02:01, given peptide DQEYNPLGE | binding porbability = 0.0000
# 20	TransPHLA report: given HLA HLA-A*02:01, given peptide DQNYNPLGE | binding porbability = 0.0000
# 21	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSYNPIGE | binding porbability = 0.0000
# 22	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSVNPLGE | binding porbability = 0.0000
# 23	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSLNPLGE | binding porbability = 0.0000
# 24	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSKNPLGE | binding porbability = 0.0000
# 25	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSFNPLGE | binding porbability = 0.0000
# 26	TransPHLA report: given HLA HLA-A*02:01, given peptide DQSINPLGE | binding porbability = 0.0000

# %% [markdown]
# # algorithm-2a HLA-A*02:01

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:01"
init_peptide = "DQTYNEMGD"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="2a"
                                        )
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:01, given peptide: DQTYNEMGD | binding porbability: 0.0000
# ************** Run algorithm-2a **************
# Iteration-1, mutant_pool size: 19
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGE | 9 D->E | binding probability: 0.0012
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGI | 9 D->I | binding probability: 0.0013
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGW | 9 D->W | binding probability: 0.0039
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGV | 9 D->V | binding probability: 0.0220
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGM | 9 D->M | binding probability: 0.0407
# Iteration-2, mutant_pool size: 95
# source peptide: DQTYNEMGV, mutated peptide: DQTYNMMGV | 6 E->M | binding probability: 0.8842
# source peptide: DQTYNEMGM, mutated peptide: DQTYNFMGM | 6 E->F | binding probability: 0.9209
# source peptide: DQTYNEMGV, mutated peptide: DQTYNLMGV | 6 E->L | binding probability: 0.9546
# source peptide: DQTYNEMGE, mutated peptide: DQTKNEMGE | 4 Y->K | binding probability: 0.9572
# source peptide: DQTYNEMGV, mutated peptide: DQTYNFMGV | 6 E->F | binding probability: 0.9709
# Iteration-3, mutant_pool size: 95
# source peptide: DQTYNLMGV, mutated peptide: FQTYNLMGV | 1 D->F | binding probability: 0.9802
# source peptide: DQTYNFMGV, mutated peptide: HQTYNFMGV | 1 D->H | binding probability: 0.9809
# source peptide: DQTYNLMGV, mutated peptide: LQTYNLMGV | 1 D->L | binding probability: 0.9852
# source peptide: DQTYNLMGV, mutated peptide: HQTYNLMGV | 1 D->H | binding probability: 0.9882
# source peptide: DQTKNEMGE, mutated peptide: DQTKNELGE | 7 M->L | binding probability: 0.9899
# Iteration-4, mutant_pool size: 95
# source peptide: FQTYNLMGV, mutated peptide: FQTENLMGV | 4 Y->E | binding probability: 0.9988
# source peptide: LQTYNLMGV, mutated peptide: LQTDNLMGV | 4 Y->D | binding probability: 0.9988
# source peptide: HQTYNFMGV, mutated peptide: HQTYNFMEV | 8 G->E | binding probability: 0.9990
# source peptide: HQTYNFMGV, mutated peptide: HQTYNFMTV | 8 G->T | binding probability: 0.9993
# source peptide: FQTYNLMGV, mutated peptide: FQTPNLMGV | 4 Y->P | binding probability: 0.9993
# Iteration-5, mutant_pool size: 95
# source peptide: FQTPNLMGV, mutated peptide: FQFPNLMGV | 3 T->F | binding probability: 0.9999
# source peptide: FQTENLMGV, mutated peptide: FQTENLVGV | 7 M->V | binding probability: 0.9999
# source peptide: FQTPNLMGV, mutated peptide: FQNPNLMGV | 3 T->N | binding probability: 1.0000
# source peptide: FQTPNLMGV, mutated peptide: FQDPNLMGV | 3 T->D | binding probability: 1.0000
# source peptide: HQTYNFMTV, mutated peptide: HQDYNFMTV | 3 T->D | binding probability: 1.0000
# -------------- Algorithm-2a done --------------

# %%
import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")

for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# target/all: 68830/924412
# pos/target: 34460/68830
# neg/target: 34370/68830
# DQTYNEMGE isn't in our dataset
# DQTYNEMGI isn't in our dataset
# DQTYNEMGW isn't in our dataset
# DQTYNEMGV isn't in our dataset
# DQTYNEMGM isn't in our dataset
# DQTYNMMGV isn't in our dataset
# DQTYNFMGM isn't in our dataset
# DQTYNLMGV isn't in our dataset
# DQTKNEMGE isn't in our dataset
# DQTYNFMGV isn't in our dataset
# FQTYNLMGV isn't in our dataset
# HQTYNFMGV isn't in our dataset
# LQTYNLMGV isn't in our dataset
# HQTYNLMGV isn't in our dataset
# DQTKNELGE isn't in our dataset
# FQTENLMGV isn't in our dataset
# LQTDNLMGV isn't in our dataset
# HQTYNFMEV isn't in our dataset
# HQTYNFMTV isn't in our dataset
# FQTPNLMGV isn't in our dataset
# FQFPNLMGV isn't in our dataset
# FQTENLVGV isn't in our dataset
# FQNPNLMGV isn't in our dataset
# FQDPNLMGV isn't in our dataset
# HQDYNFMTV isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGD | binding porbability = 0.0000
# 2	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGE | binding porbability = 0.0000
# 3	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGI | binding porbability = 0.0002
# 4	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGW | binding porbability = 0.0000
# 5	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGV | binding porbability = 0.0000
# 6	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGM | binding porbability = 0.0000
# 7	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNMMGV | binding porbability = 0.0011
# 8	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGM | binding porbability = 0.0000
# 9	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNLMGV | binding porbability = 0.0014
# 10	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTKNEMGE | binding porbability = 0.0000
# 11	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGV | binding porbability = 0.0061
# 12	TransPHLA report: given HLA HLA-A*02:01, given peptide FQTYNLMGV | binding porbability = 0.9999
# 13	TransPHLA report: given HLA HLA-A*02:01, given peptide HQTYNFMGV | binding porbability = 0.9631
# 14	TransPHLA report: given HLA HLA-A*02:01, given peptide LQTYNLMGV | binding porbability = 0.8586
# 15	TransPHLA report: given HLA HLA-A*02:01, given peptide HQTYNLMGV | binding porbability = 0.9789
# 16	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTKNELGE | binding porbability = 0.0000
# 17	TransPHLA report: given HLA HLA-A*02:01, given peptide FQTENLMGV | binding porbability = 1.0000
# 18	TransPHLA report: given HLA HLA-A*02:01, given peptide LQTDNLMGV | binding porbability = 0.9999
# 19	TransPHLA report: given HLA HLA-A*02:01, given peptide HQTYNFMEV | binding porbability = 0.9929
# 20	TransPHLA report: given HLA HLA-A*02:01, given peptide HQTYNFMTV | binding porbability = 0.9854
# 21	TransPHLA report: given HLA HLA-A*02:01, given peptide FQTPNLMGV | binding porbability = 1.0000
# 22	TransPHLA report: given HLA HLA-A*02:01, given peptide FQFPNLMGV | binding porbability = 1.0000
# 23	TransPHLA report: given HLA HLA-A*02:01, given peptide FQTENLVGV | binding porbability = 1.0000
# 24	TransPHLA report: given HLA HLA-A*02:01, given peptide FQNPNLMGV | binding porbability = 1.0000
# 25	TransPHLA report: given HLA HLA-A*02:01, given peptide FQDPNLMGV | binding porbability = 1.0000
# 26	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNFMTV | binding porbability = 0.9939

# %% [markdown]
# # algoritm2b HLA-A*02:01

# %%
import torch
from mutation import get_mutated_peptides

use_cuda = True
device = torch.device("cuda:0" if (torch.cuda.is_available() and use_cuda) else "cpu")

given_HLA = "HLA-A*02:01"
init_peptide = "DQTYNEMGD"

mutant_peptides = get_mutated_peptides(
                                        given_HLA, init_peptide, device,
                                        num_mutation=5, num_peptides=5, algorithm="2b"
                                        )
# Out:
# HLA_seq_dict preparing
# Model preparing
# given HLA: HLA-A*02:01, given peptide: DQTYNEMGD | binding porbability: 0.0000
# ************** Run algorithm-2b **************
# Iteration-1, mutant_pool size: 19
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGE | 9 D->E | binding probability: 0.0012
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGI | 9 D->I | binding probability: 0.0013
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGW | 9 D->W | binding probability: 0.0039
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGV | 9 D->V | binding probability: 0.0220
# source peptide: DQTYNEMGD, mutated peptide: DQTYNEMGM | 9 D->M | binding probability: 0.0407
# Iteration-2, mutant_pool size: 95
# source peptide: DQTYNEMGV, mutated peptide: DQTYNMMGV | 6 E->M | binding probability: 0.8842
# source peptide: DQTYNEMGM, mutated peptide: DQTYNFMGM | 6 E->F | binding probability: 0.9209
# source peptide: DQTYNEMGV, mutated peptide: DQTYNLMGV | 6 E->L | binding probability: 0.9546
# source peptide: DQTYNEMGV, mutated peptide: DQTYNFMGV | 6 E->F | binding probability: 0.9709
# source peptide: DQTYNEMGE, mutated peptide: DQTYNPMGE | 6 E->P | binding probability: 0.9785
# Iteration-3, mutant_pool size: 95
# source peptide: DQTYNLMGV, mutated peptide: MQTYNLMGV | 1 D->M | binding probability: 0.9770
# source peptide: DQTYNLMGV, mutated peptide: FQTYNLMGV | 1 D->F | binding probability: 0.9802
# source peptide: DQTYNFMGV, mutated peptide: HQTYNFMGV | 1 D->H | binding probability: 0.9809
# source peptide: DQTYNLMGV, mutated peptide: LQTYNLMGV | 1 D->L | binding probability: 0.9852
# source peptide: DQTYNLMGV, mutated peptide: HQTYNLMGV | 1 D->H | binding probability: 0.9882
# Iteration-4, mutant_pool size: 95
# source peptide: HQTYNLMGV, mutated peptide: HQPYNLMGV | 3 T->P | binding probability: 0.9982
# source peptide: MQTYNLMGV, mutated peptide: MQPYNLMGV | 3 T->P | binding probability: 0.9985
# source peptide: FQTYNLMGV, mutated peptide: FQPYNLMGV | 3 T->P | binding probability: 0.9988
# source peptide: HQTYNLMGV, mutated peptide: HQDYNLMGV | 3 T->D | binding probability: 0.9989
# source peptide: HQTYNFMGV, mutated peptide: HQDYNFMGV | 3 T->D | binding probability: 0.9990
# Iteration-5, mutant_pool size: 95
# source peptide: HQPYNLMGV, mutated peptide: HQPYNLAGV | 7 M->A | binding probability: 0.9999
# source peptide: HQDYNLMGV, mutated peptide: HQDYNLAGV | 7 M->A | binding probability: 0.9999
# source peptide: HQDYNLMGV, mutated peptide: HQDYNLIGV | 7 M->I | binding probability: 0.9999
# source peptide: HQDYNLMGV, mutated peptide: HQDYNLVGV | 7 M->V | binding probability: 1.0000
# source peptide: HQDYNFMGV, mutated peptide: HQDYNFVGV | 7 M->V | binding probability: 1.0000
# -------------- Algorithm-2b done --------------

# %%
import pandas as pd
data_path = "/data/lujd/neoag_data/main_task/"
train_data_raw = pd.read_csv(
            data_path+'train_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
val_data_raw = pd.read_csv(
            data_path+'val_data_fold4.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
test_data_raw = pd.read_csv(
            data_path+'independent_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
external_data_raw = pd.read_csv(
            data_path+'external_set.csv', index_col=0
            )[['peptide', 'HLA', 'label']]
merged_data = pd.concat([train_data_raw, val_data_raw, test_data_raw, external_data_raw], axis=0)
target_data = merged_data[merged_data.HLA==given_HLA]
pos_peptides = target_data[target_data.label==1].peptide.to_list()
neg_peptides = target_data[target_data.label==0].peptide.to_list()
print(f"target/all: {len(target_data)}/{len(merged_data)}")
print(f"pos/target: {len(pos_peptides)}/{len(target_data)}")
print(f"neg/target: {len(neg_peptides)}/{len(target_data)}")

for mutant_peptide in mutant_peptides:
    if mutant_peptide in pos_peptides:
        print(f"{mutant_peptide} is in our positive dataset")
    elif mutant_peptide in neg_peptides:
        print(f"{mutant_peptide} is in our negative dataset")
    else:
        print(f"{mutant_peptide} isn't in our dataset")
# Out:
# target/all: 68830/924412
# pos/target: 34460/68830
# neg/target: 34370/68830
# DQTYNEMGE isn't in our dataset
# DQTYNEMGI isn't in our dataset
# DQTYNEMGW isn't in our dataset
# DQTYNEMGV isn't in our dataset
# DQTYNEMGM isn't in our dataset
# DQTYNMMGV isn't in our dataset
# DQTYNFMGM isn't in our dataset
# DQTYNLMGV isn't in our dataset
# DQTYNFMGV isn't in our dataset
# DQTYNPMGE isn't in our dataset
# MQTYNLMGV isn't in our dataset
# FQTYNLMGV isn't in our dataset
# HQTYNFMGV isn't in our dataset
# LQTYNLMGV isn't in our dataset
# HQTYNLMGV isn't in our dataset
# HQPYNLMGV isn't in our dataset
# MQPYNLMGV isn't in our dataset
# FQPYNLMGV isn't in our dataset
# HQDYNLMGV isn't in our dataset
# HQDYNFMGV isn't in our dataset
# HQPYNLAGV isn't in our dataset
# HQDYNLAGV isn't in our dataset
# HQDYNLIGV isn't in our dataset
# HQDYNLVGV isn't in our dataset
# HQDYNFVGV isn't in our dataset

# %%
import numpy as np
import torch
import torch.nn as nn
from TransPHLA_model import Transformer

hla_seq_dict = pd.read_csv(
                        data_path+"HLA_sequence_dict_ABCEG.csv", index_col=0
                        ).set_index(["HLA_name"])["short"].to_dict()
HLA_seq = hla_seq_dict[given_HLA]
vocab = np.load(
            data_path+"vocab_dict.npy", allow_pickle=True
            ).item()

model_path = "/data/lujd/neoag_model/main_task/"
model_name = "TransPHLA/TransPHLA_official_model.pkl"
model_eval = Transformer()
model_eval.load_state_dict(torch.load(model_path+model_name), strict = True)
model_eval.eval()

hla_max_len = 34
pep_max_len = 15
hla_token = [vocab[n] for n in HLA_seq.ljust(hla_max_len, "-")]
hla_token = torch.LongTensor([hla_token])

# initial peptide
pep_token = [vocab[n] for n in init_peptide.ljust(pep_max_len, "-")]
pep_token = torch.LongTensor([pep_token])
val_outputs, _, _, _ = model_eval(pep_token, hla_token)
y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(1, given_HLA, init_peptide, y_prob_val.item()))

# mutate peptides
for order, mutant_peptide in enumerate(mutant_peptides):
    pep_token = [vocab[n] for n in mutant_peptide.ljust(pep_max_len, "-")]
    pep_token = torch.LongTensor([pep_token])
    val_outputs, _, _, _ = model_eval(pep_token, hla_token)
    y_prob_val = nn.Softmax(dim=1)(val_outputs)[:, 1].cpu().detach().numpy()
    print("{}\tTransPHLA report: given HLA {}, given peptide {} | binding porbability = {:.4f}".format(order+2, given_HLA, mutant_peptide, y_prob_val.item()))
# Out:
# 1	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGD | binding porbability = 0.0000
# 2	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGE | binding porbability = 0.0000
# 3	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGI | binding porbability = 0.0002
# 4	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGW | binding porbability = 0.0000
# 5	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGV | binding porbability = 0.0000
# 6	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNEMGM | binding porbability = 0.0000
# 7	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNMMGV | binding porbability = 0.0011
# 8	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGM | binding porbability = 0.0000
# 9	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNLMGV | binding porbability = 0.0014
# 10	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNFMGV | binding porbability = 0.0061
# 11	TransPHLA report: given HLA HLA-A*02:01, given peptide DQTYNPMGE | binding porbability = 0.0000
# 12	TransPHLA report: given HLA HLA-A*02:01, given peptide MQTYNLMGV | binding porbability = 0.9868
# 13	TransPHLA report: given HLA HLA-A*02:01, given peptide FQTYNLMGV | binding porbability = 0.9999
# 14	TransPHLA report: given HLA HLA-A*02:01, given peptide HQTYNFMGV | binding porbability = 0.9631
# 15	TransPHLA report: given HLA HLA-A*02:01, given peptide LQTYNLMGV | binding porbability = 0.8586
# 16	TransPHLA report: given HLA HLA-A*02:01, given peptide HQTYNLMGV | binding porbability = 0.9789
# 17	TransPHLA report: given HLA HLA-A*02:01, given peptide HQPYNLMGV | binding porbability = 0.9892
# 18	TransPHLA report: given HLA HLA-A*02:01, given peptide MQPYNLMGV | binding porbability = 0.9783
# 19	TransPHLA report: given HLA HLA-A*02:01, given peptide FQPYNLMGV | binding porbability = 0.9999
# 20	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNLMGV | binding porbability = 0.1769
# 21	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNFMGV | binding porbability = 0.8451
# 22	TransPHLA report: given HLA HLA-A*02:01, given peptide HQPYNLAGV | binding porbability = 0.9939
# 23	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNLAGV | binding porbability = 0.2646
# 24	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNLIGV | binding porbability = 0.0890
# 25	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNLVGV | binding porbability = 0.2385
# 26	TransPHLA report: given HLA HLA-A*02:01, given peptide HQDYNFVGV | binding porbability = 0.7407
